# %% [markdown]
# # Arbres de Desicions

# %% [markdown]
# Un arbre de décision est un modèle de classification hiérarchique : pour des exemples sous la représentation x = (x1; x2; : : : ; xd) 2 Rd, à chaque nœud de l’arbre est associé un test sur une des dimensions
# xi de la forme xi ≤ s avec s une valeur réelle. Ce test indique le nœud fils qui doit être sélectionné (par
# exemple pour un arbre binaire, le fils gauche quand le test est vrai, le fils droit sinon). À chaque feuille
# de l’arbre est associée une étiquette. Ainsi, la classification d’un exemple consiste en une succession de
# tests sur les valeurs des dimensions de l’exemple, selon un chemin dans l’arbre de la racine à une des
# feuilles. La feuille atteinte donne la classe prédite.
#
# L’apprentissage de l’arbre s’effectue de manière récursive gloutonne top-down : à chaque nœud, l’algorithme doit choisir un test optimal, c’est-à-dire à la fois sur quelle dimension faire le test et quel
# seuillage appliqué (ce qu’on appelle un split). La mesure d’optimalité est en général une mesure d’homogénéité sur la partition obtenue, usuellement l’entropie de Shanon ou l’index de Gini : l’entropie
# d’une partition est d’autant plus petite qu’une classe prédomine dans chaque sous-ensemble de la partition, elle est nulle lorsque la séparation est parfaite (un seul label présent dans chacune des partitions)
# et maximale lorsque l’ensemble est le plus désordonné possible (équiprobabilité des labels dans chaque
# partition).
#
# Pour calculer le split optimal, chaque dimension de l’espace de description est considérée itérativement ;
# pour une dimension i, les exemples sont triés par rapport à la valeur de l’attribut de cette dimension
# xi, puis pour chaque split possible, le calcul de l’homogénéité des deux partitions obtenues (en termes
# de label) par ce split est effectué. Le split ayant la meilleure homogénéité est alors choisi.
# Bien que l’algorithme pourrait continuer récursivement jusqu’à n’obtenir que des feuilles contenant un
# ensemble pur d’exemples (d’une seule classe), on utilise souvent des critères d’arrêts (pourquoi ? - nous
# y reviendrons lors de ce TP). Les plus utilisés sont le nombre d’exemples minimum que doit contenir
# un nœud pour être divisé (critère local) et la profondeur maximale de l’arbre (critère global)

# %%
# %load_ext autoreload

import numpy as np
from graphviz import Source
from sklearn.tree import export_graphviz
from sklearn.tree import DecisionTreeClassifier as DTree
from sklearn.ensemble import RandomForestClassifier as RFC
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd
import pickle as pk
import sys
import os

# %autoreload 2
sys.path.append("../")
from utils import imdb

# %%
#load it
datax, datay, id2titles, fields = imdb.load_data()
print("datasetSize: ", datax.shape[0])
print("numberOfFeatures : ", datax.shape[1])
print("Y labels have values of : ", np.unique(datay))
print()
print("Fields dictionary : ", fields)
print()
display(id2titles)
# Out:
# datasetSize:  4587
# numberOfFeatures :  33
# Y labels have values of :  [-1  1]
#
# Fields dictionary :  {0: 'Sci-Fi', 1: 'Crime', 2: 'Romance', 3: 'Animation', 4: 'Music', 5: 'Comedy', 6: 'War', 7: 'Horror', 8: 'Film-Noir', 9: 'Adult', 10: 'News', 11: 'Reality-TV', 12: 'Thriller', 13: 'Western', 14: 'Mystery', 15: 'Short', 16: 'Talk-Show', 17: 'Drama', 18: 'Action', 19: 'Documentary', 20: 'Musical', 21: 'History', 22: 'Family', 23: 'Adventure', 24: 'Fantasy', 25: 'Game-Show', 26: 'Sport', 27: 'Biography', 28: 'Duree', 29: 'couleur', 30: 'annee', 31: 'budget', 32: 'nb_votes', 33: 'rating'}
# {0: "'Crocodile' Dundee II",
#  1: '(500) Days of Summer',
#  2: "...E tu vivrai nel terrore! L'aldilà",
#  3: '10 Things I Hate About You',
#  4: '10,000 BC',
#  5: '101 Dalmatians',
#  6: '102 Dalmatians',
#  7: '11:14',
#  8: '12',
#  9: '12 Angry Men',
#  10: '12 Rounds',
#  11: '12 Years a Slave',
#  12: '127 Hours',
#  13: '13 Going on 30',
#  14: '13 Sins',
#  15: '1408',
#  16: '1492: Conquest of Paradise',
#  17: '15 Minutes',
#  18: '16 Blocks',
#  19: '17 Again',
#  20: '1941',
#  21: '2 Days in New York',
#  22: '2 Fast 2 Furious',
#  23: '2 Guns',
#  24: '20,000 Leagues Under the Sea',
#  25: '200 Cigarettes',
#  26: '2001 Maniacs',
#  27: '2001: A Space Odyssey',
#  28: '2010',
#  29: '2012',
#  30: '2046',
#  31: '21 & Over',
#  32: '21',
#  33: '21 Grams',
#  34: '21 Jump Street',
#  35: '22 Jump Street',
#  36: '25th Hour',
#  37: '27 Dresses',
#  38: '28 Days',
#  39: '28 Days Later...',
#  40: '3 Days to Kill',
#  41: '3 Men and a Baby',
#  42: '3 Ninjas',
#  43: '30 Days of Night',
#  44: '30 Minutes or Less',
#  45: '300',
#  46: '3000 Miles to Graceland',
#  47: '300: Rise of an Empire',
#  48: '36 Quai des Orfèvres',
#  49: '3:10 to Yuma',
#  50: '4 luni, 3 saptamâni si 2 zile',
#  51: '40 Days and 40 Nights',
#  52: '42',
#  53: '47 Ronin',
#  54: '4: Rise of the Silver Surfer',
#  55: '5 Days of War',
#  56: '50 First Dates',
#  57: '50/50',
#  58: '54',
#  59: '6 Bullets',
#  60: '6 Souls',
#  61: '8 femmes',
#  62: '8 Mile',
#  63: '88 Minutes',
#  64: '8MM',
#  65: '9',
#  66: '9 rota',
#  67: '9 Songs',
#  68: 'A Beautiful Mind',
#  69: 'A Better Life',
#  70: 'A Bridge Too Far',
#  71: 'A Bronx Tale',
#  72: "A Bug's Life",
#  73: 'A Christmas Carol',
#  74: 'A Christmas Story',
#  75: 'A Cinderella Story',
#  76: 'A Civil Action',
#  77: 'A Clockwork Orange',
#  78: 'A Cock and Bull Story',
#  79: 'A Dangerous Method',
#  80: 'A Dirty Shame',
#  81: 'A Few Good Men',
#  82: 'A Fish Called Wanda',
#  83: 'A Good Day to Die Hard',
#  84: 'A Good Year',
#  85: 'A Guy Thing',
#  86: "A Hard Day's Night",
#  87: 'A Haunted House',
#  88: 'A Haunted House 2',
#  89: 'A History of Violence',
#  90: 'A Home at the End of the World',
#  91: "A Knight's Tale",
#  92: 'A League of Their Own',
#  93: 'A Life Less Ordinary',
#  94: 'A Little Princess',
#  95: 'A Lonely Place to Die',
#  96: 'A Lot Like Love',
#  97: 'A Man Apart',
#  98: 'A Man for All Seasons',
#  99: 'A Matter of Life and Death',
#  100: "A Midsummer Night's Dream",
#  101: 'A Mighty Heart',
#  102: 'A Million Ways to Die in the West',
#  103: 'A Most Violent Year',
#  104: 'A Most Wanted Man',
#  105: 'A Night at the Roxbury',
#  106: 'A Night to Remember',
#  107: 'A Nightmare on Elm Street',
#  108: 'A Nightmare on Elm Street',
#  109: 'A Nightmare on Elm Street 3: Dream Warriors',
#  110: 'A Nightmare on Elm Street 4: The Dream Master',
#  111: "A Nightmare on Elm Street Part 2: Freddy's Revenge",
#  112: 'A Nightmare on Elm Street: The Dream Child',
#  113: 'A Passage to India',
#  114: 'A Perfect Getaway',
#  115: 'A Perfect Murder',
#  116: 'A Perfect World',
#  117: 'A Place in the Sun',
#  118: 'A Prairie Home Companion',
#  119: 'A Room with a View',
#  120: 'A Scanner Darkly',
#  121: 'A Serious Man',
#  122: 'A Simple Plan',
#  123: 'A Single Man',
#  124: 'A Sound of Thunder',
#  125: 'A Star Is Born',
#  126: 'A Streetcar Named Desire',
#  127: 'A Thousand Words',
#  128: 'A Time to Kill',
#  129: 'A Very Harold & Kumar 3D Christmas',
#  130: 'A View to a Kill',
#  131: 'A Walk Among the Tombstones',
#  132: 'A Walk in the Clouds',
#  133: 'A Walk to Remember',
#  134: 'A.R.O.G',
#  135: 'Abduction',
#  136: 'About a Boy',
#  137: 'About Last Night',
#  138: 'About Schmidt',
#  139: 'Above the Law',
#  140: 'Abraham Lincoln: Vampire Hunter',
#  141: 'Abre los ojos',
#  142: 'Absentia',
#  143: 'Absolute Power',
#  144: 'Accepted',
#  145: 'Ace in the Hole',
#  146: 'Ace Ventura: Pet Detective',
#  147: 'Ace Ventura: When Nature Calls',
#  148: 'Across the Universe',
#  149: 'Act of Valor',
#  150: 'Adaptation.',
#  151: 'Admission',
#  152: 'Affliction',
#  153: 'After Earth',
#  154: 'After Hours',
#  155: 'After the Sunset',
#  156: 'After.Life',
#  157: 'Agent Cody Banks',
#  158: 'Agent Cody Banks 2: Destination London',
#  159: 'Agneepath',
#  160: 'Agora',
#  161: 'Aguirre, der Zorn Gottes',
#  162: 'Air America',
#  163: 'Air Bud',
#  164: 'Air Force One',
#  165: 'Airplane II: The Sequel',
#  166: 'Airplane!',
#  167: 'Airport',
#  168: 'Aladdin',
#  169: 'Albert Nobbs',
#  170: 'Alex & Emma',
#  171: 'Alex Cross',
#  172: 'Alexander',
#  173: 'Alexander and the Terrible, Horrible, No Good, Very Bad Day',
#  174: 'Alexis Zorbas',
#  175: 'Alfie',
#  176: 'Ali',
#  177: 'Ali G Indahouse',
#  178: 'Alice',
#  179: "Alice Doesn't Live Here Anymore",
#  180: 'Alice in Wonderland',
#  181: 'Alice in Wonderland',
#  182: 'Alien',
#  183: 'Alien Nation',
#  184: 'Alien: Resurrection',
#  185: 'Aliens',
#  186: 'Aliens in the Attic',
#  187: 'Alien³',
#  188: 'Alive',
#  189: 'All About Steve',
#  190: 'All Dogs Go to Heaven',
#  191: 'All Is Lost',
#  192: 'All Quiet on the Western Front',
#  193: 'All the Boys Love Mandy Lane',
#  194: "All the King's Men",
#  195: "All the President's Men",
#  196: 'All the Pretty Horses',
#  197: 'Almost Famous',
#  198: 'Aloha',
#  199: 'Alone in the Dark',
#  200: 'Along Came a Spider',
#  201: 'Along Came Polly',
#  202: 'Alpha and Omega',
#  203: 'Alphaville, une étrange aventure de Lemmy Caution',
#  204: 'Alvin and the Chipmunks',
#  205: 'Alvin and the Chipmunks: Chipwrecked',
#  206: 'Alvin and the Chipmunks: The Squeakquel',
#  207: 'Always',
#  208: 'Amadeus',
#  209: 'Amen.',
#  210: "America's Sweethearts",
#  211: 'American Beauty',
#  212: 'American Dreamz',
#  213: 'American Gangster',
#  214: 'American Gigolo',
#  215: 'American Graffiti',
#  216: 'American History X',
#  217: 'American Hustle',
#  218: 'American Outlaws',
#  219: 'American Pie',
#  220: 'American Pie 2',
#  221: 'American Psycho',
#  222: 'American Reunion',
#  223: 'American Sniper',
#  224: 'American Ultra',
#  225: 'American Wedding',
#  226: 'Amistad',
#  227: 'Amores perros',
#  228: 'Amour',
#  229: 'An American Crime',
#  230: 'An American Haunting',
#  231: 'An American in Paris',
#  232: 'An American Werewolf in London',
#  233: 'An American Werewolf in Paris',
#  234: 'An Education',
#  235: 'An Ideal Husband',
#  236: 'An Officer and a Gentleman',
#  237: 'An Unfinished Life',
#  238: 'Anaconda',
#  239: 'Anacondas: The Hunt for the Blood Orchid',
#  240: 'Analyze This',
#  241: 'Anastasia',
#  242: 'Anchorman 2: The Legend Continues',
#  243: 'Anchorman: The Legend of Ron Burgundy',
#  244: 'And Now for Something Completely Different',
#  245: 'Andrey Rublyov',
#  246: 'Angel Eyes',
#  247: 'Angel Heart',
#  248: 'Angel-A',
#  249: "Angela's Ashes",
#  250: 'Angels & Demons',
#  251: 'Angels in the Outfield',
#  252: 'Anger Management',
#  253: 'Angst essen Seele auf',
#  254: 'Animal House',
#  255: 'Animal Kingdom',
#  256: 'Anna and the King',
#  257: 'Annabelle',
#  258: 'Annapolis',
#  259: 'Annie',
#  260: 'Annie',
#  261: 'Annie Hall',
#  262: 'Anonymous',
#  263: 'Another 48 Hrs.',
#  264: 'Another Year',
#  265: 'Ant-Man',
#  266: 'Antichrist',
#  267: 'Antitrust',
#  268: 'Antwone Fisher',
#  269: 'Antz',
#  270: 'Any Given Sunday',
#  271: 'Anything Else',
#  272: 'Anywhere But Here',
#  273: 'Apocalypse Now',
#  274: 'Apocalypto',
#  275: 'Apollo 13',
#  276: 'Apollo 18',
#  277: "April Fool's Day",
#  278: 'Apt Pupil',
#  279: 'Aqua Teen Hunger Force Colon Movie Film for Theaters',
#  280: 'Aquamarine',
#  281: 'Arachnophobia',
#  282: 'Arbitrage',
#  283: 'Are We There Yet?',
#  284: 'Argo',
#  285: 'Arizona Dream',
#  286: 'Arlington Road',
#  287: 'Armageddon',
#  288: 'Armored',
#  289: 'Army of Darkness',
#  290: 'Arn: Tempelriddaren',
#  291: 'Around the World in 80 Days',
#  292: 'Around the World in Eighty Days',
#  293: 'Arsenic and Old Lace',
#  294: 'Arthur',
#  295: 'Arthur',
#  296: 'Arthur et les Minimoys',
#  297: 'Artificial Intelligence: AI',
#  298: 'As Good as It Gets',
#  299: 'Assassination Games',
#  300: 'Assassination of a High School President',
#  301: 'Assassins',
#  302: 'Assault on Precinct 13',
#  303: 'Assault on Precinct 13',
#  304: 'Astro Boy',
#  305: 'Astérix & Obélix contre César',
#  306: 'Astérix & Obélix: Mission Cléopâtre',
#  307: 'Astérix aux jeux olympiques',
#  308: 'At Close Range',
#  309: 'At First Sight',
#  310: 'Atlantic City',
#  311: 'Atlantis: The Lost Empire',
#  312: 'Atlas Shrugged: Part I',
#  313: 'ATM',
#  314: 'Atonement',
#  315: 'Attack the Block',
#  316: 'August Rush',
#  317: 'August: Osage County',
#  318: 'Austenland',
#  319: 'Austin Powers in Goldmember',
#  320: 'Austin Powers: International Man of Mystery',
#  321: 'Austin Powers: The Spy Who Shagged Me',
#  322: 'Australia',
#  323: 'Auto Focus',
#  324: 'Autumn in New York',
#  325: 'Autómata',
#  326: 'Av mevsimi',
#  327: 'Avalon',
#  328: 'Avatar',
#  329: 'Avengers: Age of Ultron',
#  330: 'AVP: Alien vs. Predator',
#  331: 'AVPR: Aliens vs Predator - Requiem',
#  332: 'Awake',
#  333: 'Away from Her',
#  334: 'Away We Go',
#  335: 'Baazigar',
#  336: 'Babe',
#  337: 'Babe: Pig in the City',
#  338: 'Babel',
#  339: 'Baby Geniuses',
#  340: 'Baby Mama',
#  341: "Baby's Day Out",
#  342: 'Babylon A.D.',
#  343: 'Bacheha-Ye aseman',
#  344: 'Bachelorette',
#  345: 'Back to School',
#  346: 'Back to the Future',
#  347: 'Back to the Future Part II',
#  348: 'Back to the Future Part III',
#  349: 'Bad Boys',
#  350: 'Bad Boys II',
#  351: 'Bad Company',
#  352: 'Bad Day at Black Rock',
#  353: 'Bad Lieutenant',
#  354: 'Bad News Bears',
#  355: 'Bad Santa',
#  356: 'Bad Taste',
#  357: 'Bad Teacher',
#  358: 'Bad Words',
#  359: 'Badlands',
#  360: 'Bahubali: The Beginning',
#  361: 'Bait',
#  362: 'Bakjwi',
#  363: 'Ballistic: Ecks vs. Sever',
#  364: 'Bananas',
#  365: 'Bande à part',
#  366: 'Bandidas',
#  367: 'Bandits',
#  368: 'Bandslam',
#  369: 'Bangkok Dangerous',
#  370: 'Banlieue 13',
#  371: 'Banlieue 13: Ultimatum',
#  372: 'Baraka',
#  373: 'Barbarella',
#  374: 'Barbershop',
#  375: 'Barefoot',
#  376: 'Barfi!',
#  377: 'Barfly',
#  378: 'Barnyard',
#  379: 'Barry Lyndon',
#  380: 'Barton Fink',
#  381: 'Basic',
#  382: 'Basic Instinct',
#  383: 'Basic Instinct 2',
#  384: 'Basket Case',
#  385: 'Basquiat',
#  386: 'Batman & Robin',
#  387: 'Batman',
#  388: 'Batman Begins',
#  389: 'Batman Forever',
#  390: 'Batman Returns',
#  391: 'Batman: Mask of the Phantasm',
#  392: 'Batman: The Movie',
#  393: 'Batoru rowaiaru',
#  394: 'Batoru rowaiaru II: Chinkonka',
#  395: 'Battle for the Planet of the Apes',
#  396: 'Battle in Seattle',
#  397: 'Battle Los Angeles',
#  398: 'Battle of Britain',
#  399: 'Battlefield Earth',
#  400: 'Battleship',
#  401: 'Be Cool',
#  402: 'Be Kind Rewind',
#  403: 'Bean',
#  404: 'Beastly',
#  405: 'Beasts of No Nation',
#  406: 'Beasts of the Southern Wild',
#  407: 'Beautiful Creatures',
#  408: 'Beauty and the Beast',
#  409: 'Beavis and Butt-Head Do America',
#  410: 'Becket',
#  411: 'Becoming Jane',
#  412: 'Bedazzled',
#  413: 'Bedknobs and Broomsticks',
#  414: 'Bedtime Stories',
#  415: 'Bee Movie',
#  416: 'Beerfest',
#  417: "Beethoven's 2nd",
#  418: 'Beetlejuice',
#  419: 'Before Sunrise',
#  420: 'Before Sunset',
#  421: "Before the Devil Knows You're Dead",
#  422: 'Begin Again',
#  423: 'Beginners',
#  424: 'Behind Enemy Lines',
#  425: 'Being John Malkovich',
#  426: 'Being Julia',
#  427: 'Belle',
#  428: 'Ben X',
#  429: 'Ben-Hur',
#  430: 'Bend It Like Beckham',
#  431: 'Beneath the Planet of the Apes',
#  432: 'Beowulf',
#  433: 'Bernie',
#  434: 'Best in Show',
#  435: 'Beverly Hills Chihuahua',
#  436: 'Beverly Hills Cop',
#  437: 'Beverly Hills Cop II',
#  438: 'Beverly Hills Cop III',
#  439: 'Bewitched',
#  440: 'Beyond a Reasonable Doubt',
#  441: 'Beyond Borders',
#  442: 'Beyond the Sea',
#  443: 'Bicentennial Man',
#  444: "Bienvenue chez les Ch'tis",
#  445: 'Big',
#  446: 'Big Daddy',
#  447: 'Big Eyes',
#  448: 'Big Fat Liar',
#  449: 'Big Fish',
#  450: 'Big Game',
#  451: 'Big Hero 6',
#  452: 'Big Miracle',
#  453: "Big Momma's House",
#  454: "Big Momma's House 2",
#  455: 'Big Mommas: Like Father, Like Son',
#  456: 'Big Night',
#  457: 'Big Nothing',
#  458: 'Big Stan',
#  459: 'Big Trouble',
#  460: 'Big Trouble in Little China',
#  461: "Bill & Ted's Bogus Journey",
#  462: "Bill & Ted's Excellent Adventure",
#  463: 'Billy Elliot',
#  464: 'Billy Madison',
#  465: 'Biloxi Blues',
#  466: 'Bin-jip',
#  467: 'Bio-Dome',
#  468: 'Bird on a Wire',
#  469: 'Birdemic: Shock and Terror',
#  470: 'Birdman of Alcatraz',
#  471: 'Birdman: Or (The Unexpected Virtue of Ignorance)',
#  472: 'Birth',
#  473: 'Birthday Girl',
#  474: 'Bitter Moon',
#  475: 'Black',
#  476: 'Black Christmas',
#  477: 'Black Christmas',
#  478: 'Black Dynamite',
#  479: 'Black Hawk Down',
#  480: 'Black Knight',
#  481: 'Black Mass',
#  482: 'Black Narcissus',
#  483: 'Black Rain',
#  484: 'Black Snake Moan',
#  485: 'Black Swan',
#  486: 'Blackhat',
#  487: 'Blade',
#  488: 'Blade II',
#  489: 'Blade Runner',
#  490: 'Blade: Trinity',
#  491: 'Blades of Glory',
#  492: 'Blast from the Past',
#  493: 'Blazing Saddles',
#  494: 'Blended',
#  495: 'Bless the Child',
#  496: 'Blind Date',
#  497: 'Blindness',
#  498: 'Blood and Bone',
#  499: 'Blood Diamond',
#  500: 'Blood Simple.',
#  501: 'Blood Ties',
#  502: 'Blood Work',
#  503: 'Blood: The Last Vampire',
#  504: 'BloodRayne',
#  505: 'Bloodsport',
#  506: 'Bloody Sunday',
#  507: 'Blow',
#  508: 'Blow Out',
#  509: 'Blown Away',
#  510: 'Blowup',
#  511: 'Blue Crush',
#  512: 'Blue Jasmine',
#  513: 'Blue Ruin',
#  514: 'Blue Streak',
#  515: 'Blue Thunder',
#  516: 'Blue Valentine',
#  517: 'Blue Velvet',
#  518: 'Blues Brothers 2000',
#  519: 'Boat Trip',
#  520: 'Bobby',
#  521: 'Body Double',
#  522: 'Body of Evidence',
#  523: 'Body of Lies',
#  524: 'Body Snatchers',
#  525: 'Bodyguard',
#  526: 'Boiler Room',
#  527: 'Boksuneun naui geot',
#  528: 'Bolt',
#  529: 'Bonnie and Clyde',
#  530: 'Boogeyman',
#  531: 'Boogie Nights',
#  532: 'Book of Shadows: Blair Witch 2',
#  533: 'Boomerang',
#  534: 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#  535: 'Bordello of Blood',
#  536: 'Borgman',
#  537: 'Born on the Fourth of July',
#  538: 'Bottle Rocket',
#  539: 'Bottle Shock',
#  540: 'Bounce',
#  541: 'Bound',
#  542: 'Bound by Honor',
#  543: 'Bowfinger',
#  544: 'Bowling for Columbine',
#  545: 'Boyhood',
#  546: 'Boys and Girls',
#  547: "Boys Don't Cry",
#  548: 'Boyz n the Hood',
#  549: 'Braindead',
#  550: 'Brave',
#  551: 'Braveheart',
#  552: 'Brazil',
#  553: 'Breakdown',
#  554: "Breakfast at Tiffany's",
#  555: "Brewster's Millions",
#  556: 'Brick',
#  557: 'Brick Mansions',
#  558: 'Bride & Prejudice',
#  559: 'Bride of Chucky',
#  560: 'Bride of Frankenstein',
#  561: 'Bride Wars',
#  562: 'Bridesmaids',
#  563: 'Bridge of Spies',
#  564: 'Bridge to Terabithia',
#  565: "Bridget Jones's Diary",
#  566: 'Bridget Jones: The Edge of Reason',
#  567: 'Brief Encounter',
#  568: 'Bright Star',
#  569: 'Bring It On',
#  570: 'Bring Me the Head of Alfredo Garcia',
#  571: 'Bringing Down the House',
#  572: 'Bringing Out the Dead',
#  573: 'Bringing Up Baby',
#  574: 'Broadcast News',
#  575: 'Broadway Danny Rose',
#  576: 'Brokeback Mountain',
#  577: 'Brokedown Palace',
#  578: 'Broken Arrow',
#  579: 'Broken City',
#  580: 'Broken Flowers',
#  581: "Brooklyn's Finest",
#  582: 'Brother',
#  583: 'Brothers',
#  584: 'Brubaker',
#  585: 'Bruce Almighty',
#  586: 'Brüno',
#  587: 'Bubba Ho-Tep',
#  588: 'Bubble Boy',
#  589: 'Bud Abbott Lou Costello Meet Frankenstein',
#  590: "Buffalo '66",
#  591: 'Buffalo Soldiers',
#  592: 'Buffy the Vampire Slayer',
#  593: 'Bug',
#  594: 'Bugsy',
#  595: 'Bull Durham',
#  596: 'Bullet to the Head',
#  597: 'Bulletproof',
#  598: 'Bulletproof Monk',
#  599: 'Bullets Over Broadway',
#  600: 'Bullitt',
#  601: 'Bulworth',
#  602: 'Bunraku',
#  603: 'Buried',
#  604: 'Burke and Hare',
#  605: 'Burlesque',
#  606: 'Burn After Reading',
#  607: "But I'm a Cheerleader",
#  608: 'Butch Cassidy and the Sundance Kid',
#  609: 'Butterfly on a Wheel',
#  610: 'Byzantium',
#  611: 'Byôsoku 5 senchimêtoru',
#  612: "C'era una volta il West",
#  613: 'C.R.A.Z.Y.',
#  614: 'Cabaret',
#  615: 'Cabin Fever',
#  616: 'Caché',
#  617: 'Caddyshack',
#  618: 'Caddyshack II',
#  619: 'Cadillac Records',
#  620: 'Cake',
#  621: 'Calendar Girls',
#  622: 'Caligola',
#  623: 'Camp X-Ray',
#  624: "Can't Hardly Wait",
#  625: 'Canadian Bacon',
#  626: 'Candyman',
#  627: 'Cannibal Holocaust',
#  628: 'Cape Fear',
#  629: 'Capote',
#  630: 'Capricorn One',
#  631: 'Captain America: The First Avenger',
#  632: 'Captain America: The Winter Soldier',
#  633: "Captain Corelli's Mandolin",
#  634: 'Captain Phillips',
#  635: 'Captain Ron',
#  636: 'Captivity',
#  637: 'Carandiru',
#  638: 'Cargo',
#  639: "Carlito's Way",
#  640: 'Carnage',
#  641: 'Carnival of Souls',
#  642: 'Carrie',
#  643: 'Carrie',
#  644: 'Cars',
#  645: 'Cars 2',
#  646: 'Casa de mi Padre',
#  647: 'Casablanca',
#  648: 'Case 39',
#  649: 'Casino',
#  650: 'Casino Jack',
#  651: 'Casino Royale',
#  652: 'Casino Royale',
#  653: 'Casper',
#  654: "Cassandra's Dream",
#  655: 'Cast Away',
#  656: 'Casualties of War',
#  657: 'Cat on a Hot Tin Roof',
#  658: 'Cat People',
#  659: 'Cat People',
#  660: "Cat's Eye",
#  661: 'Catch .44',
#  662: 'Catch Me If You Can',
#  663: 'Catch-22',
#  664: 'Cats & Dogs',
#  665: 'Catwoman',
#  666: 'Cecil B. DeMented',
#  667: 'Celda 211',
#  668: 'Celebrity',
#  669: 'Cellular',
#  670: 'Center Stage',
#  671: 'Central do Brasil',
#  672: 'Chain Reaction',
#  673: 'Chalte Chalte',
#  674: 'Changeling',
#  675: 'Changing Lanes',
#  676: 'Chaos',
#  677: 'Chaplin',
#  678: 'Chappie',
#  679: 'Charade',
#  680: 'Chariots of Fire',
#  681: 'Charlie and the Chocolate Factory',
#  682: 'Charlie Bartlett',
#  683: 'Charlie St. Cloud',
#  684: "Charlie Wilson's War",
#  685: "Charlie's Angels",
#  686: "Charlie's Angels: Full Throttle",
#  687: 'Chasing Amy',
#  688: 'Chasing Liberty',
#  689: 'Chasing Mavericks',
#  690: 'Chasseurs de dragons',
#  691: 'Che: Part One',
#  692: 'Che: Part Two',
#  693: 'Cheap Thrills',
#  694: 'Cheaper by the Dozen',
#  695: 'Cheaper by the Dozen 2',
#  696: 'Chef',
#  697: 'Chi bi',
#  698: 'Chi bi Part II: Jue zhan tian xia',
#  699: 'Chicago',
#  700: 'Chicken Little',
#  701: 'Chicken Run',
#  702: 'Child 44',
#  703: "Child's Play",
#  704: "Child's Play 2",
#  705: "Child's Play 3",
#  706: 'Children of Men',
#  707: 'Children of the Corn',
#  708: 'Chinatown',
#  709: 'Chinjeolhan geumjassi',
#  710: 'Chitty Chitty Bang Bang',
#  711: 'Chloe',
#  712: 'Chocolat',
#  713: 'Choke',
#  714: 'Chopper',
#  715: 'Christiane F. - Wir Kinder vom Bahnhof Zoo',
#  716: 'Christine',
#  717: 'Christmas Vacation',
#  718: 'Christmas with the Kranks',
#  719: 'Chronicle',
#  720: 'Cidade de Deus',
#  721: 'Cinderella',
#  722: 'Cinderella',
#  723: 'Cinderella Man',
#  724: "Cirque du Freak: The Vampire's Assistant",
#  725: 'Citizen Kane',
#  726: 'City by the Sea',
#  727: 'City Hall',
#  728: 'City Island',
#  729: 'City Lights',
#  730: 'City of Angels',
#  731: 'City of Ember',
#  732: 'City Slickers',
#  733: "City Slickers II: The Legend of Curly's Gold",
#  734: 'Clash of the Titans',
#  735: 'Clash of the Titans',
#  736: 'Cleaner',
#  737: 'Cleanskin',
#  738: 'Clear and Present Danger',
#  739: 'Cleopatra',
#  740: 'Clerks',
#  741: 'Clerks II',
#  742: 'Click',
#  743: 'Cliffhanger',
#  744: 'Clockers',
#  745: 'Clockstoppers',
#  746: 'Close Encounters of the Third Kind',
#  747: 'Closer',
#  748: 'Cloud Atlas',
#  749: 'Cloudy with a Chance of Meatballs',
#  750: 'Cloverfield',
#  751: 'Club Dread',
#  752: 'Clue',
#  753: 'Clueless',
#  754: 'Coach Carter',
#  755: 'Cocktail',
#  756: 'Coco avant Chanel',
#  757: 'Cocoon: The Return',
#  758: 'Code 46',
#  759: 'Cold Mountain',
#  760: 'Collateral',
#  761: 'Collateral Damage',
#  762: 'College',
#  763: 'Colombiana',
#  764: 'Color of Night',
#  765: 'Colors',
#  766: 'Coming to America',
#  767: 'Commando',
#  768: 'Compliance',
#  769: 'Con Air',
#  770: 'Conan the Barbarian',
#  771: 'Conan the Barbarian',
#  772: 'Conan the Destroyer',
#  773: 'Confessions of a Dangerous Mind',
#  774: 'Confessions of a Teenage Drama Queen',
#  775: 'Confidence',
#  776: 'Congo',
#  777: 'Conquest of the Planet of the Apes',
#  778: 'Conspiracy Theory',
#  779: 'Constantine',
#  780: 'Contact',
#  781: 'Contagion',
#  782: 'Contraband',
#  783: 'Control',
#  784: 'Conviction',
#  785: 'Convoy',
#  786: "Cookie's Fortune",
#  787: 'Cool Runnings',
#  788: 'Cop Land',
#  789: 'Cop Out',
#  790: 'Copie conforme',
#  791: 'Copycat',
#  792: 'Copying Beethoven',
#  793: 'Coraline',
#  794: 'Corky Romano',
#  795: 'Corpse Bride',
#  796: 'Cosmopolis',
#  797: 'Country Strong',
#  798: 'Couples Retreat',
#  799: 'Courage Under Fire',
#  800: 'Courageous',
#  801: 'Cowboys & Aliens',
#  802: 'Coyote Ugly',
#  803: 'Cradle 2 the Grave',
#  804: 'Crank',
#  805: 'Crank: High Voltage',
#  806: 'Crash',
#  807: 'Crash',
#  808: 'Crazy Heart',
#  809: 'Crazy, Stupid, Love.',
#  810: 'Crazy/Beautiful',
#  811: 'Creation',
#  812: 'Creepshow',
#  813: 'Creepshow 2',
#  814: 'Crimes and Misdemeanors',
#  815: 'Crimson Peak',
#  816: 'Crimson Tide',
#  817: 'Critters',
#  818: 'Crocodile Dundee',
#  819: 'Crocodile Dundee in Los Angeles',
#  820: 'Cronos',
#  821: 'Cross of Iron',
#  822: 'Crossing Over',
#  823: 'Crossroads',
#  824: 'Cruel Intentions',
#  825: 'Cry-Baby',
#  826: 'Cry_Wolf',
#  827: 'Cube',
#  828: 'Cube Zero',
#  829: 'Cujo',
#  830: 'Curly Sue',
#  831: 'Curse of Chucky',
#  832: 'Cursed',
#  833: 'Cutthroat Island',
#  834: 'Cybernatural',
#  835: 'Cyborg',
#  836: 'Cypher',
#  837: 'Cyrus',
#  838: 'D-Tox',
#  839: 'D-War',
#  840: 'D.E.B.S.',
#  841: 'Da bing xiao jiang',
#  842: 'Dabangg',
#  843: 'Dabba',
#  844: 'Daddy Day Camp',
#  845: 'Daddy Day Care',
#  846: 'Dagon',
#  847: 'Dallas Buyers Club',
#  848: 'Damien: Omen II',
#  849: 'Dan in Real Life',
#  850: 'Dance of the Vampires',
#  851: 'Dancer in the Dark',
#  852: 'Dances with Wolves',
#  853: 'Dangerous Liaisons',
#  854: 'Danny Collins',
#  855: "Dante's Peak",
#  856: 'Daredevil',
#  857: 'Dark Blue',
#  858: 'Dark City',
#  859: 'Dark Shadows',
#  860: 'Dark Skies',
#  861: 'Dark Star',
#  862: 'Dark Water',
#  863: 'Darkman',
#  864: 'Darkness',
#  865: 'Darkness Falls',
#  866: 'Das Boot',
#  867: 'Das Cabinet des Dr. Caligari',
#  868: 'Das Leben der Anderen',
#  869: 'Das weiße Band - Eine deutsche Kindergeschichte',
#  870: 'Date Movie',
#  871: 'Date Night',
#  872: 'Dawn of the Dead',
#  873: 'Dawn of the Dead',
#  874: 'Dawn of the Planet of the Apes',
#  875: 'Day of the Dead',
#  876: 'Day of the Dead',
#  877: 'Day of the Woman',
#  878: 'Daybreakers',
#  879: 'Daylight',
#  880: 'Days of Heaven',
#  881: 'Days of Thunder',
#  882: 'Dazed and Confused',
#  883: "De battre mon coeur s'est arrêté",
#  884: "De rouille et d'os",
#  885: 'Dead Again',
#  886: 'Dead Man',
#  887: 'Dead Man on Campus',
#  888: 'Dead Man Walking',
#  889: "Dead Man's Shoes",
#  890: 'Dead Poets Society',
#  891: 'Dead Presidents',
#  892: 'Dead Ringers',
#  893: 'Dead Silence',
#  894: 'Deadfall',
#  895: 'Death and the Maiden',
#  896: 'Death at a Funeral',
#  897: 'Death at a Funeral',
#  898: 'Death Becomes Her',
#  899: 'Death Race',
#  900: 'Death Race 2000',
#  901: 'Death Sentence',
#  902: 'Death to Smoochy',
#  903: 'Death Wish',
#  904: 'December Boys',
#  905: 'Deception',
#  906: 'Deconstructing Harry',
#  907: 'Deep Blue Sea',
#  908: 'Deep Impact',
#  909: 'Deep Rising',
#  910: 'Defendor',
#  911: 'Defiance',
#  912: 'Deja Vu',
#  913: 'Delicatessen',
#  914: 'Deliver Us from Evil',
#  915: 'Deliverance',
#  916: 'Delivery Man',
#  917: 'Dellamorte Dellamore',
#  918: 'Demolition Man',
#  919: 'Den brysomme mannen',
#  920: 'Der Baader Meinhof Komplex',
#  921: 'Der Name der Rose',
#  922: 'Der Schuh des Manitu',
#  923: 'Der Untergang',
#  924: 'Derailed',
#  925: 'Dersu Uzala',
#  926: 'Des hommes et des dieux',
#  927: 'Desperado',
#  928: 'Desperate Measures',
#  929: 'Desperately Seeking Susan',
#  930: 'Despicable Me',
#  931: 'Despicable Me 2',
#  932: 'Desu nôto',
#  933: 'Desu nôto: The last name',
#  934: 'Det sjunde inseglet',
#  935: 'Detention',
#  936: 'Detroit Rock City',
#  937: 'Deuce Bigalow: European Gigolo',
#  938: 'Deuce Bigalow: Male Gigolo',
#  939: 'Deux frères',
#  940: 'Deux jours, une nuit',
#  941: 'Dev.D',
#  942: 'Devdas',
#  943: 'Devil',
#  944: 'Devil in a Blue Dress',
#  945: "Devil's Due",
#  946: "Devil's Knot",
#  947: 'Dhoom:2',
#  948: 'Dial M for Murder',
#  949: 'Diamonds Are Forever',
#  950: 'Diana',
#  951: 'Diary of a Mad Black Woman',
#  952: 'Diary of a Wimpy Kid',
#  953: 'Diary of a Wimpy Kid: Dog Days',
#  954: 'Diary of a Wimpy Kid: Rodrick Rules',
#  955: 'Diary of the Dead',
#  956: 'Dick',
#  957: 'Dick Tracy',
#  958: 'Dickie Roberts: Former Child Star',
#  959: 'Did You Hear About the Morgans?',
#  960: 'Die Another Day',
#  961: 'Die Fälscher',
#  962: 'Die Hard',
#  963: 'Die Hard 2',
#  964: 'Die Hard: With a Vengeance',
#  965: 'Die unendliche Geschichte',
#  966: 'Die Welle',
#  967: 'Dil Chahta Hai',
#  968: 'Dilwale Dulhania Le Jayenge',
#  969: 'Diner',
#  970: 'Dinosaur',
#  971: 'Dirty Dancing',
#  972: 'Dirty Dancing: Havana Nights',
#  973: 'Dirty Harry',
#  974: 'Dirty Pretty Things',
#  975: 'Dirty Work',
#  976: 'Disaster Movie',
#  977: 'Disclosure',
#  978: 'Disconnect',
#  979: 'District 9',
#  980: 'Disturbia',
#  981: 'Disturbing Behavior',
#  982: 'Divergent',
#  983: 'Divine Secrets of the Ya-Ya Sisterhood',
#  984: 'Django Unchained',
#  985: 'Dnevnoy dozor',
#  986: 'Do the Right Thing',
#  987: 'DOA: Dead or Alive',
#  988: 'Dobermann',
#  989: 'Doctor Dolittle',
#  990: 'Doctor Zhivago',
#  991: 'Dodgeball: A True Underdog Story',
#  992: 'Dog Soldiers',
#  993: 'Doghouse',
#  994: 'Dogma',
#  995: 'Dogville',
#  996: 'Dolphin Tale',
#  997: 'Domestic Disturbance',
#  998: 'Domino',
#  999: 'Don 2',
#  ...}

# %%
df = pd.DataFrame(np.hstack((datax, datay.reshape(-1, 1))), columns=fields.values())
clean = df.drop(['Adult', 'News', 'Reality-TV', 'Talk-Show', 'Game-Show'], axis=1)

# %%
corr = clean.corr()

# %%
#corr2 = clean.fillna(0)

# %%
fig, ax = plt.subplots(figsize=(15,15))
sn.heatmap(corr, annot=True, linewidths=.5, ax=ax)
plt.show()

# %% [markdown]
# ### Exercice 1: Entropie

# %% [markdown]
# Dans cette partie nous allons coder quelques fonctions utilitaire notemment l'entropie.
#
# l'entropie est définie par : $$H(Y) = -\sum_{y\in Y}{p_y \log{p_y}}$$ où $p_y$  designe la probabilité du label y dans le dataset

# %%
def entropie(vect):
    """
    Array->float
    
    Calcule l'entropie d'un vecteur
    """
    Y, py = np.unique(vect, return_counts=True)
    py = py/py.sum() # normaliser
    
    py[py==0] = 1 # pour eviter les erreurs floatants

    return -py.dot(np.log(py))


print(f"test 1 : {entropie(np.arange(10))}, expected: {np.log(10)}")
print(f"test 1 : {entropie(np.array([1]*10))}, expected: 0")
# Out:
# test 1 : 2.3025850929940455, expected: 2.302585092994046
# test 1 : -0.0, expected: 0

# %% [markdown]
# L’entropie conditionnelle permet de calculer l’homogénéité de la partition obtenue.
#
# Dans le cas général d’un split n-aire en n partitions P = fP1; : : : ; Png, l’entropie conditionnelle à P s’écrit:
#
# $$H(Y|P) = \sum_{i}{p(P_i)H(Y|P_i)}, \\ H(Y|P_i) = − \sum_{y \in Y}{p(y|Pi)\log(p(y|P_i))}$$ l’entropie des labels conditionnée à la partition considérée, et p(Pi) = PjjPjiPj jj, la proportion d’éléments dans Pi. Il s’agit en fait
# de la moyenne pondérée des entropies des sous-ensembles obtenus.

# %%
def etropie_cond(vect):
    """
    """
    
    return 0

# %% [markdown]
# ### Experiments

# %%
dt = DTree ()
dt.max_depth = 5 #on fixe la taille max de l’arbre a 5
dt.min_samples_split = 2 # nombre minimum d’exemples pour spliter un noeud
dt.fit(df.iloc[:, :-1] , df.iloc[:, -1] )

print (dt.score(df.iloc[:, :-1] , df.iloc[:, -1] ))
# dessine l’arbre dans un fichier pdf si pydot est installe .
export_graphviz (dt,
                 out_file ="tree.dot ",
                 feature_names = df.columns[:-1],
                 class_names = ["Bad", "Good"],
                 rounded = True,
                 filled= True)
# Out:
# 0.7931109657728362

# %%
# !dot -Tpng tree.dot -o tree.png

# %%
from IPython.display import Image
Image(filename='tree.png', embed=True)

# %%
# Let's split the data to train and test
from sklearn.model_selection import StratifiedShuffleSplit

#first we create a category for the median income, so that when we split, we're garanted to obtain a representative test set

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
split.split(datax, datay)
# for train_index, test_index in split.split(datax, datay):
#     strat_train_set = housing_data.loc[train_index]
#     strat_test_set  = housing_data.loc[test_index]
# Out:
# <generator object BaseShuffleSplit.split at 0x0000023B22433900>

# %%
for train_index, test_index in split.split(datax, datay):
    dt = DTree (max_depth=5, min_samples_split=2)
    dt.fit(df.iloc[train_index, :-1] , df.iloc[train_index, -1] )

    
    print ("train score : ", dt.score(df.iloc[train_index, :-1] , df.iloc[train_index, -1] ))
    print ("teest score : ", dt.score(df.iloc[test_index, :-1] , df.iloc[test_index, -1] ))
    # dessine l’arbre dans un fichier pdf si pydot est installe .
    export_graphviz (dt,
                     out_file ="train_test.dot ",
                     feature_names = df.columns[:-1],
                     class_names = ["Bad", "Good"],
                     rounded = True,
                     filled= True)
    # !dot -Tpng train_test.dot -o train_test.png
    display(Image(filename='train_test.png', embed=True))
# Out:
# train score :  0.7980376124284546
# teest score :  0.7886710239651417

# %%
def show_tree(dt, name=""):
    """
    dt: DecisionTree
    """


    # dessine l’arbre dans un fichier pdf si pydot est installe .
    export_graphviz (dt,
                     out_file = name + ".dot",
                     feature_names = df.columns[:-1],
                     class_names = ["Bad", "Good"],
                     rounded = True,
                     filled= True)
    # !dot -Tpng train_test.dot -o train_test.png
    display(Image(filename=name+".png", embed=True))


x, y = df.iloc[train_index, :-1] , df.iloc[train_index, -1]


scores_train = []
scores_test = []

split = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=42)

for i, (train_index, test_index) in enumerate(split.split(x, y)):
    
    x_trian, y_train = x[train_index, :], y[train_index]
    x_test, y_test = x[test_index, :], y[test_index]
    
    
    dt = DTree (max_depth=i, min_samples_split=2)
    dt.fit(x_train , x_test)
    score_train = dt.score(x_train, y_train)
    score_test = dt.score(x_test, y_test)
    
    scores_train.append(score_train)
    scores_test.append(score_test)
    
    
    print ("train score : ", score)
    show_tree(dt, f"dt_{i}")
    
    
plt.figure(figsize=(10, 10))
plt.ylabel("accuracy")
plt.xlabel("depth")
plt.grid()
plt.plot(scores_train, label="train_accuracy")
plt.plot(scores_test, label*"test_accuracy")
